# %% [markdown]
# <a href="https://colab.research.google.com/github/rubensolano2/derivadas/blob/main/CALCULO_DE_UNA_VARIABLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DERIVADA

# %% [markdown]
# ##INTERPRETACIÓN GEOMÉTRICA

# %% [markdown]
# Encontrar la tangente de un gráfico.
#
# Definición de una recta:
#
# Y-y0 = m (X-X0)
#
# La tangente es una linea secante de PQ tal que Q tiende a P siendo P fija y Q una variable.

# %% [markdown]
#  PANDIENTE DE LA TANGENTE: M = LIM X ->0 INCREMENTO f / INCREMENTO X

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# El punto  es Q = (El punto cuando X es 0 + el incremento de x hacia la derecha, y el valor de la funcioón F cuando sustituimos el punto anterior.

# %% [markdown]
# F´(x0)= lim incremento de x tiende a 0 (F(x0+incremento X) - F(X0)/ Incremento de X

# %% [markdown]
# Ejemplo:
#  F(x) = 1/x
#  A esto se le llama diferenciar una ecuación:
#  incremento f / incremento x = ((1/ x0+incremento X) - 1/ X0) / incremento de X

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# propiedades de las Fracciones

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ELIMINAMOS TERMINOS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# CANCLEMAOS CON LO DE FUERA

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# SUSTITUIMOS POR 0 EN EL INCREMENTO Y TENDREMOS EL RESULTADO:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Resultado: diferenciación

# %% [markdown]
# f´(X0) = -1/X0^2

# %% [markdown]
# Comprobaciones del cálculo:
# - si X tiende a infinito el resultado tiende a 0
# - el resultado es negativo <0

# %% [markdown]
# Siguiente Ejercicio:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# calcular el área debajo de la linea roja teniendo el punto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# como hemos calculado la pendiente en el punto podemos usarla para calcular la tangente

# %% [markdown]
# - para econcontra x- intercept  tenemos que coger la ecuación y hace y = 0

# %% [markdown]
# sustituyendo:

# %% [markdown]
# 0-1/x0 = (-1/x0^2)(x-x0)

# %% [markdown]
# simplificando:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# resultado:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ahora para calcular la intercepción de Y podemos usar un atajo:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Esto es debido a que tiene simetria y se puede intercambiar X por Y.
#
# Explicación:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# otra forma de comprobarlo es añadir a la ecuación X = 0 y obtendremos la intersección con Y

# %% [markdown]
# RESULTADO FINAL:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# FORMAS DE NOMBRAR A LAS DERIVADAS:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# EJEMPLO 2:

# %% [markdown]
# f(X) = x^n; n = 1,2,3,4...

# %% [markdown]
# ¿ d/dx x^n?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
